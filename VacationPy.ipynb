# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
#install hvplot environment 
# conda create -n hvplot -c pyviz -c conda-forge -c nodefaults hvplot geoviews datashader xarray pandas geopandas dask streamz networkx intake intake-xarray intake-parquet s3fs scipy spatialpandas pooch rasterio fiona plotly matplotlib jupyterlab conda activate hvplot

# conda install -c conda-forge cartopy

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  puerto ayora  -0.7393  -90.3518     28.46        91           5
# 1        1          chuy -33.6971  -53.4616     33.09        52           1
# 2        2       mataura -46.1927  168.8643      8.44        95          13
# 3        3       ushuaia -54.8000  -68.3000     10.96        71         100
# 4        4         pampa  35.5362 -100.9599      1.59        80           0
#
#    Wind Speed Country       Date
# 0        1.79      EC  2023-1-27
# 1        1.63      UY  2023-1-27
# 2        0.83      NZ  2023-1-27
# 3        1.54      AR  2023-1-27
# 4        5.14      US  2023-1-27

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
mapa = city_data_df.hvplot.points('Lng', 'Lat', geo=True, tiles = True, alpha=0.70, marker='o', 
                                    s='Humidity', c='City', hover_alpha=1, frame_height=350)

# Display the map
# YOUR CODE HERE
mapa
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
cond1 = city_data_df['Max Temp'] <= 23
cond2 = city_data_df['Humidity'] <= 60
cond3 = city_data_df['Cloudiness'] >= 20.0
ideal_cities_df = city_data_df.where(cond1 & cond2 & cond3)

# Drop any rows with null values
# YOUR CODE HERE
ideal_cities_df = ideal_cities_df.dropna()

# Display sample data
# YOUR CODE HERE
ideal_cities_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 36      36.0             codrington -38.2667  141.9667     22.51      40.0
# 57      57.0               victoria  22.2855  114.1577     17.18      34.0
# 62      62.0               tasiilaq  65.6145  -37.6368    -10.61      53.0
# 86      86.0           komsomolskiy  40.4272   71.7189      2.55      59.0
# 103    103.0              grindavik  63.8424  -22.4338      6.41      60.0
# 168    168.0                requena  39.4883   -1.1004     11.77      35.0
# 223    223.0              esperance -33.8667  121.9000     20.92      60.0
# 265    265.0              ilulissat  69.2167  -51.1000    -14.04      59.0
# 267    267.0         cabo san lucas  22.8909 -109.9124     17.93      55.0
# 269    269.0               codigoro  44.8311   12.1142     10.15      54.0
# 285    285.0                  naica  27.8500 -105.4833      2.41      60.0
# 290    290.0  los llanos de aridane  28.6585  -17.9182     21.01      59.0
# 291    291.0                 gerash  27.6652   54.1371     14.23      59.0
# 332    332.0         guerrero negro  27.9769 -114.0611     15.47      33.0
# 341    341.0                 putina -15.4667  -69.4333     13.60      57.0
# 440    440.0                  yumen  40.2833   97.2000     -5.80      45.0
# 443    443.0            sakaiminato  35.5500  133.2333      6.14      60.0
# 454    454.0              belyy yar  53.6039   91.3903      2.09      56.0
# 476    476.0            green river  41.5286 -109.4662      1.47      53.0
# 477    477.0                 alizai  33.5383   70.3462     13.02      25.0
# 490    490.0                 itoman  26.1247  127.6694     15.16      58.0
# 502    502.0              coihaique -45.5752  -72.0662     17.12      58.0
# 510    510.0          san cristobal   7.7669  -72.2250     22.25      45.0
# 529    529.0                    bam  29.1060   58.3570     12.10      56.0
#
#      Cloudiness  Wind Speed Country       Date
# 36         89.0        5.02      AU  2023-1-27
# 57         49.0        5.81      HK  2023-1-27
# 62         60.0        7.97      GL  2023-1-27
# 86        100.0        0.00      UZ  2023-1-27
# 103        75.0       15.43      IS  2023-1-27
# 168        90.0        6.40      ES  2023-1-27
# 223        97.0        6.09      AU  2023-1-27
# 265       100.0        7.07      GL  2023-1-27
# 267       100.0        1.83      MX  2023-1-27
# 269        67.0        7.23      IT  2023-1-27
# 285        26.0        0.92      MX  2023-1-27
# 290        40.0        5.14      ES  2023-1-27
# 291        30.0        1.31      IR  2023-1-27
# 332       100.0        1.51      MX  2023-1-27
# 341        45.0        1.59      PE  2023-1-27
# 440        48.0        7.19      CN  2023-1-27
# 443        75.0       10.29      JP  2023-1-27
# 454       100.0       12.00      RU  2023-1-27
# 476       100.0        3.13      US  2023-1-27
# 477       100.0        1.03      PK  2023-1-27
# 490        75.0       13.38      JP  2023-1-27
# 502        40.0        3.60      CL  2023-1-27
# 510        92.0        1.61      VE  2023-1-27
# 529        89.0        2.39      IR  2023-1-27

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = ideal_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 36              codrington      AU -38.2667  141.9667      40.0
# 57                victoria      HK  22.2855  114.1577      34.0
# 62                tasiilaq      GL  65.6145  -37.6368      53.0
# 86            komsomolskiy      UZ  40.4272   71.7189      59.0
# 103              grindavik      IS  63.8424  -22.4338      60.0
# 168                requena      ES  39.4883   -1.1004      35.0
# 223              esperance      AU -33.8667  121.9000      60.0
# 265              ilulissat      GL  69.2167  -51.1000      59.0
# 267         cabo san lucas      MX  22.8909 -109.9124      55.0
# 269               codigoro      IT  44.8311   12.1142      54.0
# 285                  naica      MX  27.8500 -105.4833      60.0
# 290  los llanos de aridane      ES  28.6585  -17.9182      59.0
# 291                 gerash      IR  27.6652   54.1371      59.0
# 332         guerrero negro      MX  27.9769 -114.0611      33.0
# 341                 putina      PE -15.4667  -69.4333      57.0
# 440                  yumen      CN  40.2833   97.2000      45.0
# 443            sakaiminato      JP  35.5500  133.2333      60.0
# 454              belyy yar      RU  53.6039   91.3903      56.0
# 476            green river      US  41.5286 -109.4662      53.0
# 477                 alizai      PK  33.5383   70.3462      25.0
# 490                 itoman      JP  26.1247  127.6694      58.0
# 502              coihaique      CL -45.5752  -72.0662      58.0
# 510          san cristobal      VE   7.7669  -72.2250      45.0
# 529                    bam      IR  29.1060   58.3570      56.0

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    # YOUR CODE HERE
    "apiKey": geoapify_key,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    params["categories"] = "accommodation.hotel"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()
    # print(name_address)

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    

# Display sample data
hotel_df
# Out:
# Starting hotel search
# codrington - nearest hotel: No hotel found
# victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# tasiilaq - nearest hotel: Angmagssalik
# komsomolskiy - nearest hotel: Hotel "Ikat House"
# grindavik - nearest hotel: The Retreat at Blue Lagoon Iceland
# requena - nearest hotel: Hotel Avenida
# esperance - nearest hotel: Hospitality
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# cabo san lucas - nearest hotel: Comfort Rooms
# codigoro - nearest hotel: Albergo Pizzeria Da Elo
# naica - nearest hotel: No hotel found
# los llanos de aridane - nearest hotel: Valle Aridane
# gerash - nearest hotel: هتل آبشار
# guerrero negro - nearest hotel: Plaza sal paraiso
# putina - nearest hotel: No hotel found
# yumen - nearest hotel: No hotel found
# sakaiminato - nearest hotel: かぐら旅館
# belyy yar - nearest hotel: No hotel found
# green river - nearest hotel: Hampton Inn & Suites
# alizai - nearest hotel: No hotel found
# itoman - nearest hotel: No hotel found
# coihaique - nearest hotel: No hotel found
# san cristobal - nearest hotel: Terra Sur
# bam - nearest hotel: هتل جهانگردی بم
#                       City Country      Lat       Lng  Humidity  \
# 36              codrington      AU -38.2667  141.9667      40.0
# 57                victoria      HK  22.2855  114.1577      34.0
# 62                tasiilaq      GL  65.6145  -37.6368      53.0
# 86            komsomolskiy      UZ  40.4272   71.7189      59.0
# 103              grindavik      IS  63.8424  -22.4338      60.0
# 168                requena      ES  39.4883   -1.1004      35.0
# 223              esperance      AU -33.8667  121.9000      60.0
# 265              ilulissat      GL  69.2167  -51.1000      59.0
# 267         cabo san lucas      MX  22.8909 -109.9124      55.0
# 269               codigoro      IT  44.8311   12.1142      54.0
# 285                  naica      MX  27.8500 -105.4833      60.0
# 290  los llanos de aridane      ES  28.6585  -17.9182      59.0
# 291                 gerash      IR  27.6652   54.1371      59.0
# 332         guerrero negro      MX  27.9769 -114.0611      33.0
# 341                 putina      PE -15.4667  -69.4333      57.0
# 440                  yumen      CN  40.2833   97.2000      45.0
# 443            sakaiminato      JP  35.5500  133.2333      60.0
# 454              belyy yar      RU  53.6039   91.3903      56.0
# 476            green river      US  41.5286 -109.4662      53.0
# 477                 alizai      PK  33.5383   70.3462      25.0
# 490                 itoman      JP  26.1247  127.6694      58.0
# 502              coihaique      CL -45.5752  -72.0662      58.0
# 510          san cristobal      VE   7.7669  -72.2250      45.0
# 529                    bam      IR  29.1060   58.3570      56.0
#
#                              Hotel Name
# 36                       No hotel found
# 57              四季酒店 Four Seasons Hotel
# 62                         Angmagssalik
# 86                   Hotel "Ikat House"
# 103  The Retreat at Blue Lagoon Iceland
# 168                       Hotel Avenida
# 223                         Hospitality
# 265   Best Western Plus Hotel Ilulissat
# 267                       Comfort Rooms
# 269             Albergo Pizzeria Da Elo
# 285                      No hotel found
# 290                       Valle Aridane
# 291                           هتل آبشار
# 332                   Plaza sal paraiso
# 341                      No hotel found
# 440                      No hotel found
# 443                               かぐら旅館
# 454                      No hotel found
# 476                Hampton Inn & Suites
# 477                      No hotel found
# 490                      No hotel found
# 502                      No hotel found
# 510                           Terra Sur
# 529                     هتل جهانگردی بم

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
mapb = hotel_df.hvplot.points('Lng', 'Lat', 
    geo=True, tiles = True, alpha=0.70, marker='o', 
    frame_width = 700, frame_height = 500,
    s='Humidity', c='City', 
    hover_alpha=1, 
    hover_cols=['Hotel Name', 'Country']
)
# Display the map
# YOUR CODE HERE
mapb
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
